# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import re


df = pd.read_parquet('../habr_articles_parsed_final.parquet', engine='pyarrow')
# Out:
# /Users/georgij/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# Сразу уберем из рассмотрения статьи, где нет контента, не будем их рассматривать

# %%
df = df[~df["Content"].isna()].reset_index(drop=True)

# %% [markdown]
# Начнем с того, что рассмотрим что именно представляют из себя таргетные теги

# %%
df['Tags'].str.split(', ').explode().value_counts()
# Out:
# Tags
# javascript           6065
# python               5863
# программирование     4826
# android              4621
# разработка           4358
#                      ...
# Radeon RX 5600 XT       1
# Ryzen 7 4800U           1
# Ryzen 7 4800H           1
# udp streaming           1
# некопипасть             1
# Name: count, Length: 238850, dtype: int64

# %%
tags = df['Tags'].str.split(', ').explode()
unique_tags = tags.value_counts().index

# %% [markdown]
# Мы видим, что сейчас 238850 уникальных тегов, хотелось бы сильно сократить их количество

# %% [markdown]
# # Анализируем теги через семантическую модель

# %%
from sentence_transformers import SentenceTransformer

# Загружаем предобученную модель
model_name = 'sentence-transformers/distiluse-base-multilingual-cased-v1'
model = SentenceTransformer(model_name)

# %%
# Получаем эмбеддинги для тегов
vector_matrix = model.encode(tags.value_counts().index)

# %%
vector_matrix.shape
# Out:
# (238850, 512)

# %% [markdown]
# ## DBScan Clustering

# %%
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import cosine_similarity

# Строим модель кластеризации, чтобы объединить теги по группам и убрать лишниз представителей
dbscan = DBSCAN(eps=0.1, min_samples=3, metric="cosine", n_jobs=10).fit(vector_matrix)
labels_dbscan = dbscan.labels_
unique_labels_dbscan = set(labels_dbscan)
print(len(unique_labels_dbscan))
# Out:
# 9001

# %% [markdown]
# Посмотрим на группы

# %%
tags.value_counts().index[labels_dbscan == 1]
# Out:
# Index(['android', 'Android', 'android development', 'андроид',
#        'разработка под android', 'android sdk', 'android os',
#        'android разработка', 'андроид разработка', 'Андроид',
#        ...
#        'AndroidWear', 'Андроид разработка', 'androzic', 'Андроиды',
#        'Androidandme', 'android-development', 'abdroid',
#        'разработка по android', 'Android.Xiny', 'AndroidOS'],
#       dtype='object', name='Tags', length=111)

# %%
mapping_tags_dbscan = dict(zip(unique_tags, labels_dbscan))

# %%
from tqdm import tqdm


unique_representation_dbscan = {label : unique_tags[labels_dbscan == label][0] for label in set(labels_dbscan)}
df["tags_classes_dbscan"] = None
for idx, item in tqdm(df.iterrows()):
    item_tags = item["Tags"].split(', ')
    class_tags = set()
    for item_tag in item_tags:
        if mapping_tags_dbscan[item_tag] > 0:
            class_tags.add(unique_representation_dbscan[mapping_tags_dbscan[item_tag]]) # уникальный представитель
        else:
            class_tags.add(item_tag)
        df.loc[idx, "tags_classes_dbscan"] = ", ".join(list(class_tags))
# Out:
# 285498it [01:16, 3735.50it/s]

# %%
unique_tags_dbscan = df['tags_classes_dbscan'].str.split(', ').explode().value_counts()
unique_tags_dbscan
# Out:
# tags_classes_dbscan
# искусственный интеллект     7526
# google                      7293
# машинное обучение           7085
# android                     6920
# linux                       6334
#                             ...
# sqlite4                        1
# профессиональное будущее       1
# SQLite cusom function          1
# приложение для Aндроид         1
# некопипасть                    1
# Name: count, Length: 186936, dtype: int64

# %% [markdown]
# Хотелось бы все равно оставить меньше тегов, желательно около 100

# %%
unique_tags_dbscan[unique_tags_dbscan > 1000]
# Out:
# tags_classes_dbscan
# искусственный интеллект    7526
# google                     7293
# машинное обучение          7085
# android                    6920
# linux                      6334
#                            ...
# юзабилити                  1020
# наука                      1018
# психология                 1016
# twitter                    1013
# selectel                   1013
# Name: count, Length: 134, dtype: int64

# %% [markdown]
# Вот так звучит намного лучше. У нас будет минимум 1000 статей для каждого тега, будет проще обучить модель и предсказания будут стабильнее

# %%
unique_tags_dbscan_to_save = unique_tags_dbscan[unique_tags_dbscan > 1000].index

for idx, item in df.iterrows():
    item_tags_dbscan = item["tags_classes_dbscan"].split(', ')
    popular_tags = []
    for tag in item_tags_dbscan:
        if tag in unique_tags_dbscan_to_save:
            popular_tags.append(tag)
    df.loc[idx, "tags_classes_dbscan"] = ", ".join(popular_tags)

# %% [markdown]
# # Kmeans Clustering

# %% [markdown]
# Проделываем аналогичную процедуру с Kmeans

# %%
import numpy as np
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics.pairwise import cosine_similarity

from sklearn import preprocessing

matrix_norm = preprocessing.normalize(vector_matrix) # нормализация нужна, чтобы было равносильно подсчету косинусного расстоянию

kmeans = KMeans(n_clusters=200, random_state=0).fit(matrix_norm)

# %%
labels_kmeans = kmeans.predict(matrix_norm)

# %%
tags.value_counts().index[labels_kmeans == 20]
# Out:
# Index(['астрономия', 'asterisk', 'nasa', 'Марс', 'lua', 'луна', 'спутники',
#        'Луна', 'eclipse', 'НАСА',
#        ...
#        'Suborbital', 'SKY', 'itplanet', 'звездный воитель', 'follow the moon',
#        'starfalltactics', 'астроциты', '100 000 звёзд', 'meteorite',
#        'azure sphere'],
#       dtype='object', name='Tags', length=1245)

# %%
mapping_tags_kmeans = dict(zip(unique_tags, labels_kmeans))

# %%
unique_representation = {label : unique_tags[labels_kmeans == label][0] for label in set(labels_kmeans)}
df["tags_classes_kmeans"] = None
for idx, item in tqdm(df.iterrows()):
    item_tags = item["Tags"].split(', ')
    class_tags = set()
    for item_tag in item_tags:
        if mapping_tags_kmeans[item_tag] > 0:
            class_tags.add(unique_representation[mapping_tags_kmeans[item_tag]]) # уникальный представитель
        else:
            class_tags.add(item_tag)
        df.loc[idx, "tags_classes_kmeans"] = ", ".join(list(class_tags))
# Out:
# 285498it [01:17, 3664.13it/s]

# %%
unique_tags_kmeans = df['tags_classes_kmeans'].str.split(', ').explode().value_counts()
unique_tags_kmeans
# Out:
# tags_classes_kmeans
# frontend             34333
# ios                  25411
# devops               25405
# c                    25162
# javascript           16547
#                      ...
# темная жидкость          1
# синтез днк               1
# водяной лед              1
# colonial pipeline        1
# батарей                  1
# Name: count, Length: 1926, dtype: int64

# %% [markdown]
# Удалось сократить количество, но хочется меньше

# %%
unique_tags_kmeans[unique_tags_kmeans > 1000]
# Out:
# tags_classes_kmeans
# frontend         34333
# ios              25411
# devops           25405
# c                25162
# javascript       16547
#                  ...
# unreal engine     1335
# accessibility     1179
# async             1150
# функции           1070
# часы              1008
# Name: count, Length: 199, dtype: int64

# %% [markdown]
# Подходит, теперь уберем лишнее

# %%
unique_tags_kmeans_to_save = unique_tags_kmeans[unique_tags_kmeans > 1000].index

for idx, item in df.iterrows():
    item_tags_kmeans = item["tags_classes_kmeans"].split(', ')
    popular_tags = []
    for tag in item_tags_kmeans:
        if tag in unique_tags_kmeans_to_save:
            popular_tags.append(tag)
    df.loc[idx, "tags_classes_kmeans"] = ", ".join(popular_tags)

# %% [markdown]
# # Смотрим что получилось

# %%
df.head(50)
# Out:
#                                                 Title        Author  \
# 0                              Лечение приступов лени       complex
# 1                    Как я работал по два часа в день     Konovalov
# 2                                 Итоги первой недели        Irokez
# 3         Правильно поставленная задача время бережет        object
# 4              ChatterBlocker или Вон из моей головы!       waitekk
# 5          Каким образом вы узнали то, что вы знаете?     ASPushkin
# 6        Организация рабочего времени с помощью цвета      popotam2
# 7                             Enlarge your timus now!         Bobos
# 8                                    Мегапланирование        Irokez
# 9                                      Обмен услугами       4orever
# 10  судьба маленького разработчика в большой компа...      pavellob
# 11                    Дата-майнинг на службе у эйчара        alizar
# 12  Контроль потерянного времени на Flash: «Обновл...  COOL_ALMANAH
# 13  Полная чаша: работа дома, с женой и маленьким ...    dkuznetsov
# 14     Жизненный цикл профессии программиста. Часть 2       questor
# 15                                        Ящик мыслей    jasiejames
# 16                   Когда достигнут потолок зарплаты       ZakharS
# 17    Оптимизация работы. Электронный документооборот    UrbanRider
# 18            Многозадачность мозга можно тренировать        alizar
# 19                                           Ленимся!        koshak
# 20  Регистрация в качестве Индивидуального предпри...          voff
# 21                    Главное — верно раздробить дела    Somebody32
# 22        Как правильно говорить с «трудным» клиентом        yanajy
# 23                                Дайте мне работать!           RVK
# 24          5 вещей которые должны знать ваши клиенты          Kerf
# 25                  Дэвиду Аллену хватает Lotus Notes        alizar
# 26                             Переведите мне на VISA     dark_ruby
# 27                         Изображение на каждый день        Irokez
# 28  И жнец, и швец, и на дуде игрец — специалист п...       exelens
# 29  10 фраз, после которых ваше резюме отложат в с...      mdemidov
# 30  Маленькая практика по системе «Пятнадцать минут».        shidan
# 31  Как использовать онлайн секундомер для увеличе...     dreamhelg
# 32  Издержки больших проектов или взгляд на програ...       ZakharS
# 33                          8 советов для соискателей       Liferay
# 34                              Чего хотят заказчики?      aosodoev
# 35      Программа для обучения эффективному разговору        alizar
# 36                          Список дел на каждый день        Irokez
# 37     Где лучше: в крупной компании или в небольшой?     NikKurkov
# 38           Ускорение верстки — да поможет Notepad++      TecHMeaT
# 39  Вопрос: но как развить силу воли если нету сил...        corvus
# 40                                   iОстров iДураков        koshak
# 41              Управление, направленное на результат     godfather
# 42  Мой путь в качестве дистанционного сотрудника :-)    Catheriine
#
#                                                  Tags  \
# 0      лень, учись работать, самомотивация, мотивация
# 1   тайм-менеджмент, timemanagement, работа, эффек...
# 2                  тайм-менеджмент, пинарик, ворктрек
# 3                     постановка задачи, планирование
# 4                               chatterblocker, аудио
# 5                                 Joe Stagner, работа
# 6   развитие, работоспособность, организация дел, ...
# 7   Организация личного времени, time management, ...
# 8   ворктрек, тайм-менеджмент, планирование, време...
# 9                              работа, обмен услугами
# 10  работа, мотивация, управление проектами, размы...
# 11  дата-майнинг, HR-менеджер, теория решеток, Cat...
# 12     Flash, работа, время, контроль, шахматные часы
# 13  работа дома, фриланс, удаленка, семья и дети, ...
# 14  профессия, бизнес-процесс, психология, личност...
# 15           идея, бизнес, мозговой штурм, менеджмент
# 16                         карьера, IT, финансы, рост
# 17         Работа, оптимизация, электронные документы
# 18  многозадачность, мозг, рассеянное внимание, тр...
# 19                                               лень
# 20                                      freelance, ИП
# 21  планирование, дела, разделение, работоспособность
# 22  конфликты, клиенты, заказчики, психология, биз...
# 23                     работа, опыт, знание, развитие
# 24            бизнес, корпорации, веб-дизайн, контент
# 25  Getting Things Done, GTD, Дэвид Аллен, Things,...
# 26             оплата, карты оплаты, visa, mastercard
# 27                       ворктрек, multicolr, пинарик
# 28                        работа, кризис, HR, рабство
# 29                        hr-менеджер, работа, резюме
# 30  тайм-менеджмент, таймменеджмент, тайм менеджме...
# 31                          производительность, время
# 32  работа в команде, большие проекты, процессы, T...
# 33            работа, поиск работы, советы соискателю
# 34           заказчики, разработка сайтов, требования
# 35  совещания, групповой подкаст, модерация, эффек...
# 36           ворктрек, пинарик, список дел, todo list
# 37                               компании, корпорации
# 38                        notepad, html, css, верстка
# 39  самосовершенствование, тайм-драйв, привычки, п...
# 40              остров дураков, Николай Носов, думать
# 41        результат, управление, менеджмент, mindfuck
# 42  удаленная работа, дистанционные работники, кар...
# 43  устойчивая экономика, развитие компании, идеол...
# 44   музыка, офис, рабочее место, КПД, радио, Веб 2.0
# 45  электронная почта, im, skype, время, эффективн...
# 46  freelance, elance.com, удалённая работа, веб-д...
# 47               оптимизация, мотивация, саморазвитие
# 48                                  работа, идеология
# 49                                   GTD, mac, iphone
#
#                                               Content  Comments   Views  \
# 0   Пора лишать девственности свой бложик.\nТак ка...        67    6800
# 1   Когда я только перешёл от офисной работы к дом...        99   21000
# 2   Итак, за прошедшую неделю хабраюзеры попробова...        29    1000
# 3   Хочу поделиться своими мыслями по оптимизации ...        95   18000
# 4   Как-то привык я к тому, что предметы вокруг ме...        56    5700
# 5   Я получил это электронное письмо сегодня от Ма...        81    2500
# 6   Предлагаю еще один вариант сделать себя более ...        13    3100
# 7   Привет, %username%.\nВчера я осознал, что снов...       130    1200
# 8   В\nВорктреке\nс сегодняшнего дня появилась воз...        57    1100
# 9   Для всех, кто испытывает финансовые проблемы, ...        55    6600
# 10  Сначала необязательное предисловие. За этот то...       162    1600
# 11  Отделы кадров крупнейших IT-компаний использую...        51    2400
# 12  Таймер обновился\n, теперь им, надеюсь, будет ...        22    1300
# 13  Прочитал тему про\nработу дома 2 часа в день\n...       193   33000
# 14  Навеяно последними спорами на Хабре "\nПрограм...        29   13000
# 15  Публикую идею из цикла — «Попробуйте у себя в ...        27    2600
# 16  Хочу сразу предупредить, что несмотря на два э...       314    6700
# 17  Введение\nДоброго вам времени суток, уважаемые...        82    7400
# 18  Как известно, человеческий мозг демонстрирует ...       133   23000
# 19  Столько обсуждений борьбы с ленью,\nжуть прост...        45    2800
# 20  После моей статьи «\nFreelance: ожидания, реал...       112   17000
# 21  Сегодня я хочу рассказать (и обсудить) с вами ...        67    1200
# 22  Многим из нас время от времени попадаются «при...        81   62000
# 23  Нет, вы не так поняли. Я не сказал «работУ». Я...       215    3100
# 24  <img align=«left» title="" border=«0» alt="" s...         3     892
# 25  Дэвид Аллен\n, который в 2002 году придумал ко...         4    3000
# 26  Не так давно оплачивая один небольшой проект к...       183    6700
# 27  В недавнем\nхабратопике\nбыла ссылка на интере...         9     795
# 28  Знакомый HR попросил оценить вакансию «специал...       206     916
# 29  На\nTechRepublic\nопубликована любопытная заме...        14   14000
# 30  Вдогонку к топику про систему тайм-менеджмента...         6    2800
# 31  Время — ценный товар и оно легко тратится в он...         5    3800
# 32  Ни для кого не секрет, что разработка больших ...       112    3800
# 33  Ситуация на рынке труда в связи с кризисом осл...         5     712
# 34  Однажды, когда я только начал доставать до вер...        55    1400
# 35  Д-р Алекс Пентланд (Alex Pentland) и его колле...         2    1300
# 36  Теперь в пинарике можно составлять список дел ...        16    7500
# 37  Я работаю в небольшой компании и меня все устр...       159   13000
# 38  Я уже довольно-таки давно верстаю в\nNotepad++...       206  103000
# 39  В одних\nкомментариях\nпрозвучал такой вопрос:...       119   38000
# 40  Прочитав\nтопик про улетучивающиеся мысли\nя в...        54     913
# 41  в ответ на\nэтот пост\n, кратко об основах «go...        14    3300
# 42  Давно хотела написать подобную статью, но всё ...        94    1100
# 43  Work on Stuff that Matters: First Principles\n...        39   10000
# 44  Песня нам строить и жить помогает. Практически...       195   63000
# 45  Пост написан от некоторого отчаяния. Дело в то...       195    3500
# 46  Итак, в предыдущей части (\nКак начать работат...        24   63000
# 47  Как многие, читая хабр и литературу, которая п...       103   10000
# 48  Эта заметка должна была стать первой главой кн...        62     746
# 49  Я пишу этот топик, потому что потратил $100 на...        81   28000
#
#                                     URL  Reading_time  \
# 0   https://habr.com/ru/articles/66091/           2.0
# 1   https://habr.com/ru/articles/65783/           3.0
# 2   https://habr.com/ru/articles/59272/           1.0
# 3   https://habr.com/ru/articles/58889/           3.0
# 4   https://habr.com/ru/articles/60989/           1.0
# 5   https://habr.com/ru/articles/63367/           5.0
# 6   https://habr.com/ru/articles/64586/           1.0
# 7   https://habr.com/ru/articles/61705/           3.0
# 8   https://habr.com/ru/articles/63706/           1.0
# 9   https://habr.com/ru/articles/62053/           1.0
# 10  https://habr.com/ru/articles/61642/           3.0
# 11  https://habr.com/ru/articles/54615/           2.0
# 28                                                         individual     123
# 29                                                         individual       2
# 30  https://habrastorage.org/r/w1560/getpro/megamo...      individual       5
# 31  https://habrastorage.org/r/w780q1/getpro/megam...      individual       1
# 32  https://habrastorage.org/getpro/megamozg/post_...      individual      70
# 33                                                         individual       2
# 34                                                         individual      55
# 35                                                         individual       3
# 36  http://worktrek.com/public/img/site/todo-1.png...      individual       0
# 37  https://habr.com/images/px.gif#%3D%22http%3A%2...      individual      36
# 38  https://habrastorage.org/r/w1560/getpro/megamo...      individual      88
# 39                                                         individual     120
# 40                                                         individual      40
# 41  https://habrastorage.org/r/w780q1/files/501/da...      individual      19
# 42                     http://img.mchost.ru/iwork.jpg      individual      24
# 43  https://habrastorage.org/r/w780q1/getpro/megam...      individual     112
# 44  https://habrastorage.org/r/w1560/getpro/megamo...      individual      66
# 45                                                         individual     203
# 46             http://sergeychik.ru/images/elance.gif      individual      33
# 47                                                         individual      66
# 48  https://habrastorage.org/getpro/megamozg/post_...      individual      29
# 49  https://habrastorage.org/r/w1560/getpro/megamo...      individual      24
#
#    Positive/Negative  Bookmarks_cnt  \
# 0           positive           25.0
# 1           positive          114.0
# 2           positive            5.0
# 3           positive           75.0
# 4           positive           33.0
# 5           positive          165.0
# 6           positive            6.0
# 7           positive           57.0
# 8           positive           29.0
# 9           positive            8.0
# 10          positive           33.0
# 11          positive           25.0
# 12          positive            6.0
# 13          positive           70.0
# 14          positive           52.0
# 15          positive           19.0
# 16          positive          104.0
# 17          positive           26.0
# 18          positive           68.0
# 19          positive           16.0
# 20          positive          153.0
# 21          positive           30.0
# 22          positive          180.0
# 23          positive           45.0
# 24          positive           16.0
# 25          positive            4.0
# 26          positive           64.0
# 27          positive            2.0
# 28          positive           19.0
# 29          positive           41.0
# 30          positive           11.0
# 31          positive            5.0
# 32          positive           70.0
# 33          negative            5.0
# 34          positive           18.0
# 35          positive            3.0
# 36          positive            5.0
# 37          positive           15.0
# 38          positive          165.0
# 39          positive          142.0
# 40          positive            5.0
# 41          positive           34.0
# 42          negative           10.0
# 43          positive          157.0
# 44          positive           65.0
# 45          positive           50.0
# 46          positive          180.0
# 47          positive           46.0
# 48          positive           20.0
# 49          positive           49.0
#
#                                   tags_classes_dbscan  \
# 0
# 1                                              работа
# 2
# 3
# 4
# 5                                              работа
# 6                                  разработка, бизнес
# 7
# 8
# 9                                              работа
# 10  управление проектами, искусственный интеллект,...
# 11
# 12                                 менеджмент, работа
# 13
# 14              программирование, карьера, психология
# 15        искусственный интеллект, менеджмент, бизнес
# 16                                   финансы, карьера
# 17                                оптимизация, работа
# 18                            искусственный интеллект
# 19
# 20
# 21                                             бизнес
# 22                         бизнес, психология, работа
# 23                                 разработка, работа
# 24                                it-компании, бизнес
# 25
# 26
# 27
# 28                                             работа
# 29                                             работа
# 30
# 31                                 производительность
# 32
# 33                                             работа
# 34
# 35                                        конференция
# 36
# 37                                        it-компании
# 38                                          html, css
# 39
# 40                            искусственный интеллект
# 41                искусственный интеллект, менеджмент
# 42                 карьера, интернет, хостинг, работа
# 43
# 44                                    Веб 2.0, музыка
# 45                                            mail.ru
# 46                                             работа
# 47                         оптимизация, автоматизация
# 48                                             работа
# 49                                              apple
#
#                                   tags_classes_kmeans
# 0                психология, монетизация, карьера, ml
# 1   бизнес, карьера, timeweb_статьи, менеджмент, п...
# 2                    raspberry pi, менеджмент, devops
# 3                                планирование, ошибки
# 4                                   звук, конференция
# 5                                 Стив Джобс, карьера
# 6               frontend, бизнес, разработка, карьера
# 7                             timeweb_статьи, freebsd
# 8           планирование, графика, менеджмент, devops
# 9                                    сервисы, карьера
# 10  карьера, минимализм, психология, дизайн, монет...
# 11  менеджмент, теория вероятностей, юзабилити, ru...
# 12   управление, flash, карьера, timeweb_статьи, часы
# 13  diy или сделай сам, бизнес, умный дом, фриланс...
# 14  бизнес, программирование, карьера ит-специалис...
# 15            frontend, менеджмент, бизнес, нейросети
# 16                     финансы, ИИ, карьера, frontend
# 17                 документация, оптимизация, карьера
# 18  карьера ит-специалиста, unity, монетизация, не...
# 19                                                 ml
# 20                                       freebsd, ООП
# 21             планирование, unity, карьера, frontend
# 22  физика, бизнес, конференция, ошибки, карьера, ...
# 23  frontend, карьера ит-специалиста, разработка, ...
# 24                       статистика, браузеры, бизнес
# 25   статистика, Илон Маск, дата-центр, git, frontend
# 26                           финансы, карты, frontend
# 27                        raspberry pi, unity, devops
# 28                            монетизация, карьера, C
# 29                  менеджмент, ruvds_статьи, карьера
# 30              пиратство, timeweb_статьи, менеджмент
# 31                 timeweb_статьи, производительность
# 32              МКС, процессоры, ООП, карьера, дизайн
# 33             поиск, карьера ит-специалиста, карьера
# 34            статистика, браузеры, распознавание лиц
# 35                      команда, конференция, моддинг
# 36                   raspberry pi, статистика, devops
# 37                                             бизнес
# 38                           регистрация, php, devops
# 39  санкт-петербург, оптимизация, разработка, time...
# 40                       minecraft, Node.js, frontend
# 41             юмор, frontend, менеджмент, управление
# 42             умный дом, интернет, highload, карьера
# 43  статистика, бизнес, разработка, база знаний, ф...
# 44  Веб 2.0, документация, ООП, карьера, музыка, р...
# 45  конференция, timeweb_статьи, telegram, произво...
# 46                   браузеры, freebsd, .net, карьера
# 47            оптимизация, монетизация, автоматизация
# 48                                психология, карьера
# 49                                         git, apple

# %%
df['tags_classes_kmeans'].str.split(', ').explode().value_counts()
# Out:
# tags_classes_kmeans
# frontend         34333
# ios              25411
# devops           25405
# c                25162
# javascript       16547
#                  ...
# accessibility     1179
# async             1150
# функции           1070
# часы              1008
#                     69
# Name: count, Length: 200, dtype: int64

# %%
df['tags_classes_dbscan'].str.split(', ').explode().value_counts()
# Out:
# tags_classes_dbscan
#                            107286
# искусственный интеллект      7526
# google                       7293
# машинное обучение            7085
# android                      6920
#                             ...
# юзабилити                    1020
# наука                        1018
# психология                   1016
# selectel                     1013
# twitter                      1013
# Name: count, Length: 135, dtype: int64

# %%
df[["Content", "URL", "tags_classes_dbscan", "tags_classes_kmeans"]].to_parquet("data_for_training.parquet")
